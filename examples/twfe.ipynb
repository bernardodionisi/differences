# %% [markdown]
# # TWFE

# %%
from differences import simulate_data, TWFE

# %% [markdown]
# see [plotto](https://plotto.readthedocs.io/en/latest/notebooks/plotto.html#Plot-parameters) to configure the plots. the .plot() method takes the same arguments as the function [mark_plot() in plotto](https://plotto.readthedocs.io/en/latest/api_reference/plotto.html#plotto.plotto.mark_plot)

# %%
panel_data = simulate_data()  # generate data

panel_data
# Out:
#                      y        x0         w  cat.0  cat.1  effect  cohort  \
# entity time
# e0     1900   3.575880  0.160245  3.729827      0      0    0.00  1901.0
#        1901   3.608329 -1.933404  1.691201      0      0    0.00  1901.0
#        1902   5.132523 -0.056813  1.786326      0      0    0.50  1901.0
#        1903  -6.316240  0.810118  1.741609      0      0    1.00  1901.0
#        1904   3.409524  0.101205  0.806004      0      0    1.50  1901.0
# ...                ...       ...       ...    ...    ...     ...     ...
# e999   1903  11.376111  1.355023  0.688025      0      0   15.75  1900.0
#        1904  11.727819 -0.381267  1.952084      0      0   21.00  1900.0
#        1905  19.238415 -0.258604  1.801049      0      0   26.25  1900.0
#        1906  40.145541  1.504564  0.616657      0      0   31.50  1900.0
#        1907  70.673952  0.472740  0.674045      0      0   36.75  1900.0
#
#              intensity
# entity time
# e0     1900       0.50
#        1901       0.50
#        1902       0.50
#        1903       0.50
#        1904       0.50
# ...                ...
# e999   1903       5.25
#        1904       5.25
#        1905       5.25
#        1906       5.25
#        1907       5.25
#
# [8000 rows x 8 columns]

# %%
twfe = TWFE(
    data=panel_data,
    cohort_name="cohort",
)

# %%
twfe.fit(
    formula="y",
    cluster_names="entity",
)
# Out:
#            parameter  std_error     t_stat       p_value      lower      upper
# Intercept   3.393059   0.522830   6.489798  8.595147e-11   2.368332   4.417787
# -6         -2.154907   0.972402  -2.216067  2.668692e-02  -4.060780  -0.249035
# -5         -4.080347   1.082333  -3.769953  1.632780e-04  -6.201681  -1.959012
# -4         -3.972220   1.106781  -3.588985  3.319678e-04  -6.141471  -1.802969
# -3         -6.289177   1.103977  -5.696839  1.220494e-08  -8.452931  -4.125422
# -2         -6.490823   0.965235  -6.724601  1.760747e-11  -8.382650  -4.598997
# 0          -4.155830   0.684287  -6.073228  1.253646e-09  -5.497007  -2.814652
# 1           0.995493   0.873086   1.140200  2.542031e-01  -0.715725   2.706710
# 2           0.345642   1.016629   0.339988  7.338657e-01  -1.646915   2.338199
# 3           1.859629   1.032120   1.801756  7.158380e-02  -0.163290   3.882548
# 4           6.899893   1.000331   6.897612  5.288436e-12   4.939281   8.860504
# 5           9.578089   1.067022   8.976468  0.000000e+00   7.486764  11.669413
# 6          13.382329   1.203794  11.116791  0.000000e+00  11.022936  15.741723
# 7          27.039997   1.365123  19.807740  0.000000e+00  24.364406  29.715589

# %%
twfe.plot()
# Out:
# alt.HConcatChart(...)
