# %% [markdown]
# # TWFE

# %%
from differences import simulate_data, TWFE

# %% [markdown]
# see [plotto](https://plotto.readthedocs.io/en/latest/notebooks/plotto.html#Plot-parameters) to configure the plots. the .plot() method takes the same arguments as the function [mark_plot() in plotto](https://plotto.readthedocs.io/en/latest/api_reference/plotto.html#plotto.plotto.mark_plot)

# %%
panel_data = simulate_data()  # generate data

panel_data
# Out:
#                      y        x0         w  cat.0  cat.1  effect  cohort  \
# entity time
# e0     1900 -17.435849  0.160245  3.729827      0      0     0.0  1907.0
#        1901  -2.976963 -1.933404  1.691201      0      0     0.0  1907.0
#        1902 -19.987348 -0.056813  1.786326      0      0     0.0  1907.0
#        1903   0.400817  0.810118  1.741609      0      0     0.0  1907.0
#        1904   8.516277  0.101205  0.806004      0      0     0.0  1907.0
# ...                ...       ...       ...    ...    ...     ...     ...
# e999   1903  15.230323  1.355023  0.688025      0      0     0.0  1907.0
#        1904  12.624847 -0.381267  1.952084      0      0     0.0  1907.0
#        1905  17.858101 -0.258604  1.801049      0      0     0.0  1907.0
#        1906  10.423968  1.504564  0.616657      0      0     0.0  1907.0
#        1907  17.097119  0.472740  0.674045      0      0     0.0  1907.0
#
#              intensity
# entity time
# e0     1900        0.5
#        1901        0.5
#        1902        0.5
#        1903        0.5
#        1904        0.5
# ...                ...
# e999   1903        0.5
#        1904        0.5
#        1905        0.5
#        1906        0.5
#        1907        0.5
#
# [8000 rows x 8 columns]

# %%
twfe = TWFE(
    data=panel_data,
    cohort_name="cohort",
)

# %%
twfe.fit(
    formula="y",
    cluster_names="entity",
)
# Out:
#            parameter  std_error     t_stat       p_value      lower      upper
# Intercept   0.327144   0.358025   0.913747  3.608499e-01  -0.374572   1.028861
# -7          3.047304   1.088275   2.800123  5.108313e-03   0.914324   5.180283
# -6          3.210500   1.234374   2.600914  9.297573e-03   0.791172   5.629829
# -5          0.752813   0.990368   0.760135  4.471740e-01  -1.188272   2.693899
# -4          0.157583   1.110397   0.141916  8.871463e-01  -2.018754   2.333920
# -3          1.919482   0.686314   2.796798  5.161174e-03   0.574331   3.264632
# -2          1.725255   0.859180   2.008026  4.464049e-02   0.041294   3.409216
# 0          -0.100838   0.720495  -0.139956  8.886944e-01  -1.512982   1.311307
# 1           5.575942   0.685581   8.133168  4.440892e-16   4.232228   6.919655
# 2          12.642471   0.861807  14.669723  0.000000e+00  10.953360  14.331582
# 3          20.944586   0.810838  25.830778  0.000000e+00  19.355372  22.533800
# 4          29.389794   0.949606  30.949476  0.000000e+00  27.528601  31.250986
# 5          45.155578   1.066087  42.356368  0.000000e+00  43.066086  47.245071
# 6          55.762701   1.186833  46.984472  0.000000e+00  53.436552  58.088850

# %%
twfe.plot()
# Out:
# alt.HConcatChart(...)
