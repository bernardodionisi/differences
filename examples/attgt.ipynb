# %% [markdown]
# # ATTgt

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 6)

from differences import simulate_data, ATTgt

# %% [markdown]
# see [plotto](https://plotto.readthedocs.io/en/latest/notebooks/plotto.html#Plot-parameters) to configure the plots. the .plot() method takes the same arguments as the function [mark_plot() in plotto](https://plotto.readthedocs.io/en/latest/api_reference/plotto.html#plotto.plotto.mark_plot)

# %% [markdown]
# ## Binary Treatment

# %% [markdown]
# An entity can be either treated or not treated, and once treated it remains treated, the groups are identified by the date of the treatement (cohort)

# %%
panel_data = simulate_data()  # generate data

panel_data
# Out:
#                      y        x0         w  cat.0  cat.1  effect  cohort  \
# entity time
# e0     1900 -13.222893  0.160245  3.729827      0      0    0.00     NaN
#        1901 -10.414957 -1.933404  1.691201      0      0    0.00     NaN
#        1902 -10.291021 -0.056813  1.786326      0      0    0.00     NaN
# ...                ...       ...       ...    ...    ...     ...     ...
# e999   1905   5.932741 -0.258604  1.801049      0      0   10.50  1903.0
#        1906  19.477712  1.504564  0.616657      0      0   15.75  1903.0
#        1907  25.502489  0.472740  0.674045      0      0   21.00  1903.0
#
#              intensity
# entity time
# e0     1900        NaN
#        1901        NaN
#        1902        NaN
# ...                ...
# e999   1905       5.25
#        1906       5.25
#        1907       5.25
#
# [8000 rows x 8 columns]

# %%
att_gt = ATTgt(data=panel_data, cohort_name="cohort")

# %%
att_gt.fit(
    formula="y ~ x0",
)
# Out:
# Computing ATTgt [workers=1]   100%|████████████████████| 21/21 [00:00<00:00, 40.84it/s]
#                         ATTgtResult                                            \
#                                      analytic pointwise conf. band
#                                 ATT std_error                lower      upper
# cohort base_period time
# 1901   1900        1901   -2.532830  1.283998            -5.049419  -0.016241
#                    1902   12.858403  1.408921            10.096969  15.619837
#                    1903   20.264493  1.280211            17.755325  22.773661
# ...                             ...       ...                  ...        ...
# 1903   1902        1905    9.664153  1.287028             7.141625  12.186681
#                    1906   13.923037  1.288879            11.396881  16.449193
#                    1907   19.725716  1.388902            17.003517  22.447915
#
#
#
#                         zero_not_in_cband
# cohort base_period time
# 1901   1900        1901                 *
#                    1902                 *
#                    1903                 *
# ...                                   ...
# 1903   1902        1905                 *
#                    1906                 *
#                    1907                 *
#
# [21 rows x 5 columns]

# %%
att_gt.plot(configure_axisX={"format": "c"})
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ### Aggregate

# %%
att_gt.aggregate("time")
att_gt.plot("time", configure_axisX={"format": "c"})
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("event")
att_gt.plot("event")
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("cohort")
att_gt.plot("cohort", lines=False, configure_axisX={"format": "c"})
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("simple")
# Out:
#   SimpleAggregation                                            \
#                      analytic pointwise conf. band
#                 ATT std_error                lower      upper
# 0         15.502858  0.734802            14.062672  16.943044
#
#
#
#   zero_not_in_cband
# 0                 *

# %%
att_gt.aggregate("simple")
# Out:
#   SimpleAggregation                                            \
#                      analytic pointwise conf. band
#                 ATT std_error                lower      upper
# 0         15.502858  0.734802            14.062672  16.943044
#
#
#
#   zero_not_in_cband
# 0                 *

# %%
att_gt.aggregate("event", overall=True)
# Out:
#   EventAggregationOverall                                            \
#                            analytic pointwise conf. band
#                       ATT std_error                lower      upper
# 0               20.294689  0.693922            18.934626  21.654752
#
#
#
#   zero_not_in_cband
# 0                 *

# %% [markdown]
# ### Heterogeneity & Triple Difference

# %%
panel_data = simulate_data(samples=3)

# %%
att_gt = ATTgt(data=panel_data, cohort_name="cohort")

# heterogeneity

att_gt.fit(formula="y", split_sample_by="samples")
# Out:
# Computing ATTgt for samples = 1 [workers=1]100%|████████████████████| 14/14 [00:00<00:00, 86.51it/s]
# Computing ATTgt for samples = 0 [workers=1]100%|████████████████████| 14/14 [00:00<00:00, 91.64it/s]
# Computing ATTgt for samples = 2 [workers=1]100%|████████████████████| 14/14 [00:00<00:00, 82.11it/s]
#                                     ATTgtResult            \
#                                                  analytic
#                                             ATT std_error
# sample_name cohort base_period time
# samples = 1 1901   1900        1901    2.246080  2.324171
#                                1902    6.870490  2.102513
#                                1903   13.520126  2.388901
# ...                                         ...       ...
# samples = 2 1906   1904        1905   -0.436600  2.189753
#                    1905        1906   -0.852155  2.149348
#                                1907    5.829726  2.058110
#
#                                                                      \
#                                     pointwise conf. band
#                                                    lower      upper
# sample_name cohort base_period time
# samples = 1 1901   1900        1901            -2.309210   6.801371
#                                1902             2.749640  10.991340
#                                1903             8.837967  18.202285
# ...                                                  ...        ...
# samples = 2 1906   1904        1905            -4.728436   3.855237
#                    1905        1906            -5.064799   3.360490
#                                1907             1.795904   9.863548
#
#
#
#                                     zero_not_in_cband
# sample_name cohort base_period time
# samples = 1 1901   1900        1901
#                                1902                 *
#                                1903                 *
# ...                                               ...
# samples = 2 1906   1904        1905
#                    1905        1906
#                                1907                 *
#
# [42 rows x 5 columns]

# %%
att_gt.aggregate("event")

att_gt.plot("event", vertical_line=0, horizontal_line=0)
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("simple")
# Out:
#             SimpleAggregation                                            \
#                                analytic pointwise conf. band
#                           ATT std_error                lower      upper
# sample_name
# samples = 1         17.871952  1.595956            14.743936  20.999968
# samples = 0         24.023878  1.714008            20.664484  27.383271
# samples = 2         23.071185  1.470314            20.189423  25.952947
#
#
#
#             zero_not_in_cband
# sample_name
# samples = 1                 *
# samples = 0                 *
# samples = 2                 *

# %%
att_gt.plot(
    "simple",
    y_title=["Sample", "Names"],
    vertical_line=0,
    configure_axisY={"domain": True, "ticks": True},
)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Triple Difference

# %%
att_gt.sample_names
# Out:
# ['samples = 1', 'samples = 0', 'samples = 2']

# %%
att_gt.aggregate("time", difference=["samples = 1", "samples = 2"])
# Out:
#                                DifferenceTimeAggregation            \
#                                                           analytic
#                                                      ATT std_error
# difference_between        time
# samples = 1 - samples = 2 1901                 -3.189143  1.567639
#                           1902                 -5.769892  1.487590
#                           1903                 -4.344895  1.623100
# ...                                                  ...       ...
#                           1905                 -6.050362  1.623525
#                           1906                 -7.587888  1.762904
#                           1907                 -3.753066  1.683977
#
#                                                                \
#                                pointwise conf. band
#                                               lower     upper
# difference_between        time
# samples = 1 - samples = 2 1901            -6.261659 -0.116627
#                           1902            -8.685514 -2.854270
#                           1903            -7.526112 -1.163678
# ...                                             ...       ...
#                           1905            -9.232411 -2.868312
#                           1906           -11.043115 -4.132660
#                           1907            -7.053600 -0.452532
#
#
#
#                                zero_not_in_cband
# difference_between        time
# samples = 1 - samples = 2 1901                 *
#                           1902                 *
#                           1903                 *
# ...                                          ...
#                           1905                 *
#                           1906                 *
#                           1907                 *
#
# [7 rows x 5 columns]

# %%
att_gt.plot("time", difference=True)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Multi-valued Treatment

# %% [markdown]
# An entity can be treated with different intensities or not treated, the groups are identified by the date of the treatement (cohort) & the intensity which represents a second dimension.

# %%
panel_data = simulate_data(intensity_by=2)  # generate data

panel_data
# Out:
#                      y        x0         w  cat.0  cat.1  effect  cohort  \
# entity time
# e0     1900  -5.528611  0.160245  3.729827      0      0     0.0  1906.0
#        1901  -7.903840 -1.933404  1.691201      0      0     0.0  1906.0
#        1902  -5.650560 -0.056813  1.786326      0      0     0.0  1906.0
# ...                ...       ...       ...    ...    ...     ...     ...
# e999   1905   4.612933 -0.258604  1.801049      0      0     0.0  1906.0
#        1906  16.524228  1.504564  0.616657      0      0     0.0  1906.0
#        1907  13.204368  0.472740  0.674045      0      0     0.5  1906.0
#
#              strata  intensity
# entity time
# e0     1900     0.0        0.5
#        1901     0.0        0.5
#        1902     0.0        0.5
# ...             ...        ...
# e999   1905     0.0        0.5
#        1906     0.0        0.5
#        1907     0.0        0.5
#
# [8000 rows x 9 columns]

# %%
att_gt = ATTgt(data=panel_data, cohort_name="cohort", strata_name="strata")

# %%
att_gt.fit(formula="y", n_jobs=1)
# Out:
# Computing ATTgt [workers=1]   100%|████████████████████| 42/42 [00:01<00:00, 37.06it/s]
#                                 ATTgtResult                                 \
#                                              analytic pointwise conf. band
#                                         ATT std_error                lower
# stratum cohort base_period time
# 0       1903   1900        1901    0.937822  1.622633            -2.242480
#                1901        1902   -0.879096  1.701761            -4.214486
#                1902        1903   -0.223170  1.630224            -3.418349
# ...                                     ...       ...                  ...
# 1       1906   1904        1905    0.241531  1.517982            -2.733659
#                1905        1906   -1.393149  1.577122            -4.484251
#                            1907    9.333019  1.655273             6.088743
#
#
#
#                                      upper zero_not_in_cband
# stratum cohort base_period time
# 0       1903   1900        1901   4.118124
#                1901        1902   2.456294
#                1902        1903   2.972010
# ...                                    ...               ...
# 1       1906   1904        1905   3.216720
#                1905        1906   1.697952
#                            1907  12.577296                 *
#
# [42 rows x 5 columns]

# %% [markdown]
# ### Aggregate

# %%
att_gt.aggregate("event")
# Out:
#                         EventAggregation                                 \
#                                           analytic pointwise conf. band
#                                      ATT std_error                lower
# stratum relative_period
# 0       -5                      2.020270  1.602640            -1.120847
#         -4                     -2.344803  1.571268            -5.424432
#         -3                      2.111273  1.146943            -0.136695
# ...                                  ...       ...                  ...
# 1        2                     20.401258  1.136923            18.172930
#          3                     29.105050  1.131463            26.887423
#          4                     39.464083  1.551862            36.422490
#
#
#
#                              upper zero_not_in_cband
# stratum relative_period
# 0       -5                5.161387
#         -4                0.734827
#         -3                4.359241
# ...                            ...               ...
# 1        2               22.629587                 *
#          3               31.322677                 *
#          4               42.505677                 *
#
# [20 rows x 5 columns]

# %%
att_gt.plot("event")
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("event", difference=[0, 1], boot_iterations=5000)
# Out:
# Bootstrap                     100%|████████████████████| [00:00<00:00, 7826.94it/s]
#                                    DifferenceEventAggregation            \
#                                                               bootstrap
#                                                           ATT std_error
# difference_between relative_period
# 0 - 1              -5                                1.726495  1.636504
#                    -4                               -1.736910  1.743409
#                    -3                                1.640260  1.202479
# ...                                                       ...       ...
#                     2                              -19.541031  1.214806
#                     3                              -27.781985  1.294433
#                     4                              -37.634616  1.700595
#
#                                                                   \
#                                    simult. conf. band
#                                                 lower      upper
# difference_between relative_period
# 0 - 1              -5                       -2.809049   6.262039
#                    -4                       -6.568740   3.094920
#                    -3                       -1.692391   4.972910
# ...                                               ...        ...
#                     2                      -22.907845 -16.174216
#                     3                      -31.369485 -24.194485
#                     4                      -42.347787 -32.921446
#
#
#
#                                    zero_not_in_cband
# difference_between relative_period
# 0 - 1              -5
#                    -4
#                    -3
# ...                                              ...
#                     2                              *
#                     3                              *
#                     4                              *
#
# [10 rows x 5 columns]

# %%
att_gt.plot("event", difference=True)
# Out:
# alt.HConcatChart(...)

# %%
att_gt.aggregate("simple")
att_gt.plot("simple")
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ### Heterogeneity & Triple Difference

# %%
panel_data = simulate_data(intensity_by=2, samples=3)  # generate data

panel_data
# Out:
#                      y        x0         w  cat.0  cat.1  effect  cohort  \
# entity time
# e0     1900 -12.857954  0.160245  3.729827      0      0     0.0  1901.0
#        1901  15.286468 -1.933404  1.691201      0      0     0.0  1901.0
#        1902  12.220134 -0.056813  1.786326      0      0     4.3  1901.0
# ...                ...       ...       ...    ...    ...     ...     ...
# e999   1905  47.994393 -0.258604  1.801049      0      0    40.0  1901.0
#        1906  40.127015  1.504564  0.616657      0      0    50.0  1901.0
#        1907  60.390505  0.472740  0.674045      0      0    60.0  1901.0
#
#              samples  strata  intensity
# entity time
# e0     1900        1     0.0        4.3
#        1901        1     0.0        4.3
#        1902        1     0.0        4.3
# ...              ...     ...        ...
# e999   1905        1     1.0       10.0
#        1906        1     1.0       10.0
#        1907        1     1.0       10.0
#
# [8000 rows x 10 columns]

# %%
att_gt = ATTgt(data=panel_data, cohort_name="cohort", strata_name="strata")

# %%
att_gt.fit(formula="y", split_sample_by="samples")
# Out:
# Computing ATTgt for samples = 1 [workers=1]100%|████████████████████| 42/42 [00:00<00:00, 72.80it/s]
# Computing ATTgt for samples = 0 [workers=1]100%|████████████████████| 42/42 [00:00<00:00, 74.31it/s]
# Computing ATTgt for samples = 2 [workers=1]100%|████████████████████| 42/42 [00:00<00:00, 73.96it/s]
#                                             ATTgtResult            \
#                                                          analytic
#                                                     ATT std_error
# sample_name stratum cohort base_period time
# samples = 1 0       1901   1900        1901   -1.302368  2.943118
#                                        1902    3.408351  2.330216
#                                        1903    4.720254  2.551084
# ...                                                 ...       ...
# samples = 2 1       1907   1904        1905    2.475786  2.489134
#                            1905        1906    0.389117  2.897511
#                            1906        1907    1.735012  3.422052
#
#                                                                             \
#                                             pointwise conf. band
#                                                            lower     upper
# sample_name stratum cohort base_period time
# samples = 1 0       1901   1900        1901            -7.070773  4.466037
#                                        1902            -1.158789  7.975491
#                                        1903            -0.279779  9.720288
# ...                                                          ...       ...
# samples = 2 1       1907   1904        1905            -2.402828  7.354400
#                            1905        1906            -5.289901  6.068135
#                            1906        1907            -4.972086  8.442111
#
#
#
#                                             zero_not_in_cband
# sample_name stratum cohort base_period time
# samples = 1 0       1901   1900        1901
#                                        1902
#                                        1903
# ...                                                       ...
# samples = 2 1       1907   1904        1905
#                            1905        1906
#                            1906        1907
#
# [126 rows x 5 columns]

# %%
att_gt.aggregate("time")

att_gt.plot(
    "time",
    configure_header={"titleFontSize": 18, "labelFontSize": 15},
    estimation_details=False,
    configure_axisX={"format": "c"},
)
# Out:
# alt.ConcatChart(...)

# %%
att_gt.aggregate("time", difference=[0, 1])
# Out:
#                                     DifferenceTimeAggregation            \
#                                                                analytic
#                                                           ATT std_error
# sample_name difference_between time
# samples = 1 0 - 1              1901                 -0.598522  3.421114
#                                1902                -11.152777  2.893434
#                                1903                 -8.183168  2.459773
# ...                                                       ...       ...
# samples = 2 0 - 1              1905                 -6.362172  2.256908
#                                1906                 -5.609266  2.328508
#                                1907                 -7.530014  2.874552
#
#                                                                     \
#                                     pointwise conf. band
#                                                    lower     upper
# sample_name difference_between time
# samples = 1 0 - 1              1901            -7.303783  6.106738
#                                1902           -16.823804 -5.481749
#                                1903           -13.004234 -3.362101
# ...                                                  ...       ...
# samples = 2 0 - 1              1905           -10.785631 -1.938713
#                                1906           -10.173059 -1.045473
#                                1907           -13.164032 -1.895996
#
#
#
#                                     zero_not_in_cband
# sample_name difference_between time
# samples = 1 0 - 1              1901
#                                1902                 *
#                                1903                 *
# ...                                               ...
# samples = 2 0 - 1              1905                 *
#                                1906                 *
#                                1907                 *
#
# [21 rows x 5 columns]

# %%
att_gt.sample_names
# Out:
# ['samples = 1', 'samples = 0', 'samples = 2']

# %%
att_gt.aggregate("time", difference=["samples = 2", "samples = 0"])
# Out:
#                                        DifferenceTimeAggregation            \
#                                                                   analytic
#                                                              ATT std_error
# stratum difference_between        time
# 0       samples = 2 - samples = 0 1901                 -3.509223  1.890046
#                                   1902                  4.520457  1.938178
#                                   1903                  8.228263  1.508153
# ...                                                          ...       ...
# 1       samples = 2 - samples = 0 1905                 19.541830  1.631958
#                                   1906                 22.654308  1.682130
#                                   1907                 21.765914  1.610870
#
#                                                                         \
#                                        pointwise conf. band
#                                                       lower      upper
# stratum difference_between        time
# 0       samples = 2 - samples = 0 1901            -7.213645   0.195200
#                                   1902             0.721697   8.319216
#                                   1903             5.272337  11.184189
# ...                                                     ...        ...
# 1       samples = 2 - samples = 0 1905            16.343252  22.740409
#                                   1906            19.357394  25.951223
#                                   1907            18.608668  24.923161
#
#
#
#                                        zero_not_in_cband
# stratum difference_between        time
# 0       samples = 2 - samples = 0 1901
#                                   1902                 *
#                                   1903                 *
# ...                                                  ...
# 1       samples = 2 - samples = 0 1905                 *
#                                   1906                 *
#                                   1907                 *
#
# [14 rows x 5 columns]

# %% [markdown]
# ## Custom Estimation & DoubleML

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# outcome model
outcome_model = RandomForestRegressor(n_estimators=100, max_depth=2)

# propensity score model
pscore_model = RandomForestClassifier(n_estimators=100, max_depth=2)

# %%
from functools import partial
from differences.did.double_ml import aiptw_double_ml_did_panel

# use partial to set those models for cross-fitting

aiptw = partial(
    aiptw_double_ml_did_panel,
    pscore_model=pscore_model,
    outcome_model=outcome_model,
    outcome_type="continuous",
)

# %%
# now, instead of selecting from the menu of options available for the est_method,
# we plug in the function we composed above

att_gt.fit(
    formula="y ~ x0",
    n_jobs=-1,
    est_method=aiptw,  # <--- plug in here
    progress_bar=False,
)
# Out:
#                                 ATTgtResult                                 \
#                                              analytic pointwise conf. band
#                                         ATT std_error                lower
# stratum cohort base_period time
# 0       1901   1900        1901   -2.666891  1.682846            -5.965208
#                            1902    1.120003  1.596939            -2.009940
#                            1903    4.987098  1.659903             1.733747
# ...                                     ...       ...                  ...
# 1       1907   1904        1905    0.372545  1.617626            -2.797942
#                1905        1906   -0.576503  1.667783            -3.845298
#                1906        1907    2.024022  1.795397            -1.494891
#
#
#
#                                     upper zero_not_in_cband
# stratum cohort base_period time
# 0       1901   1900        1901  0.631426
#                            1902  4.249946
#                            1903  8.240449                 *
# ...                                   ...               ...
# 1       1907   1904        1905  3.543033
#                1905        1906  2.692291
#                1906        1907  5.542936
#
# [42 rows x 5 columns]
